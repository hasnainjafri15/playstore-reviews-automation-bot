# %%
import pandas as pd

# %%
df = pd.read_csv("final output.csv")
df
# Out:
#    Unnamed: 0                                              Jazaa  \
# 0           0  Amazing and so much friendly app to purchase g...
# 1           1  May be I'm the first user of this this aap, th...
# 2           2  Jazaa foods are totally hygienic and top notch...
# 3           3                                  Very good service
# 4           4                                                NaN
# 5           5                                                NaN
# 6           6                                                NaN
#
#                                   Char Grill Central  \
# 0  There is a huge bug in this app, which needs i...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
# ...
